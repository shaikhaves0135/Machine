# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
head = ["user_id","art_galleries","dance_clubs","juice bars","restaurants","museums","resorts","parks/picnis_spot","beaches","theaters","religious_institution"]
df = pd.read_csv("C://Users/HP/Downloads/tripadvisor_review.csv",names = head)

# %%
df
# Out:
#       user_id art_galleries dance_clubs  juice bars restaurants     museums  \
# 0     User ID    Category 1  Category 2  Category 3  Category 4  Category 5
# 1      User 1          0.93         1.8        2.29        0.62         0.8
# 2      User 2          1.02         2.2        2.66        0.64        1.42
# 3      User 3          1.22         0.8        0.54        0.53        0.24
# 4      User 4          0.45         1.8        0.29        0.57        0.46
# ..        ...           ...         ...         ...         ...         ...
# 976  User 976          0.74        1.12         0.3        0.53        0.88
# 977  User 977          1.25        0.92        1.12        0.38        0.78
# 978  User 978          0.61        1.32        0.67        0.43         1.3
# 979  User 979          0.93         0.2        0.13        0.43         0.3
# 980  User 980          0.93        0.56        1.13        0.51        1.34
#
# ...

# %%
df.drop([0],inplace = True)

# %%
for i in df.iloc[:,1:]:
    df[i] = df[i].astype("float64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 1 to 980
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                980 non-null    object
#  1   art_galleries          980 non-null    float64
#  2   dance_clubs            980 non-null    float64
#  3   juice bars             980 non-null    float64
#  4   restaurants            980 non-null    float64
#  5   museums                980 non-null    float64
#  6   resorts                980 non-null    float64
#  7   parks/picnis_spot      980 non-null    float64
#  8   beaches                980 non-null    float64
#  9   theaters               980 non-null    float64
#  10  religious_institution  980 non-null    float64
# dtypes: float64(10), object(1)
# memory usage: 84.3+ KB

# %%
numcols = df.iloc[:,1:]
numcols
# Out:
#      art_galleries  dance_clubs  juice bars  restaurants  museums  resorts  \
# 1             0.93         1.80        2.29         0.62     0.80     2.42
# 2             1.02         2.20        2.66         0.64     1.42     3.18
# 3             1.22         0.80        0.54         0.53     0.24     1.54
# 4             0.45         1.80        0.29         0.57     0.46     1.52
# 5             0.51         1.20        1.18         0.57     1.54     2.02
# ..             ...          ...         ...          ...      ...      ...
# 976           0.74         1.12        0.30         0.53     0.88     1.38
# 977           1.25         0.92        1.12         0.38     0.78     1.68
# 978           0.61         1.32        0.67         0.43     1.30     1.78
# 979           0.93         0.20        0.13         0.43     0.30     0.40
# 980           0.93         0.56        1.13         0.51     1.34     2.36
#
#      parks/picnis_spot  beaches  theaters  religious_institution
# ...

# %%
df.describe()
# Out:
#        art_galleries  dance_clubs  juice bars  restaurants     museums  \
# count     980.000000   980.000000  980.000000   980.000000  980.000000
# mean        0.893194     1.352612    1.013306     0.532500    0.939735
# std         0.326912     0.478280    0.788607     0.279731    0.437430
# min         0.340000     0.000000    0.130000     0.150000    0.060000
# 25%         0.670000     1.080000    0.270000     0.410000    0.640000
# 50%         0.830000     1.280000    0.820000     0.500000    0.900000
# 75%         1.020000     1.560000    1.572500     0.580000    1.200000
# max         3.220000     3.640000    3.620000     3.440000    3.300000
#
#           resorts  parks/picnis_spot     beaches    theaters  \
# count  980.000000         980.000000  980.000000  980.000000
# mean     1.842898           3.180939    2.835061    1.569439
# std      0.539538           0.007824    0.137505    0.364629
# min      0.140000           3.160000    2.420000    0.740000
# ...

# %%
x = numcols

# %%
x
# Out:
#      art_galleries  dance_clubs  juice bars  restaurants  museums  resorts  \
# 1             0.93         1.80        2.29         0.62     0.80     2.42
# 2             1.02         2.20        2.66         0.64     1.42     3.18
# 3             1.22         0.80        0.54         0.53     0.24     1.54
# 4             0.45         1.80        0.29         0.57     0.46     1.52
# 5             0.51         1.20        1.18         0.57     1.54     2.02
# ..             ...          ...         ...          ...      ...      ...
# 976           0.74         1.12        0.30         0.53     0.88     1.38
# 977           1.25         0.92        1.12         0.38     0.78     1.68
# 978           0.61         1.32        0.67         0.43     1.30     1.78
# 979           0.93         0.20        0.13         0.43     0.30     0.40
# 980           0.93         0.56        1.13         0.51     1.34     2.36
#
#      parks/picnis_spot  beaches  theaters  religious_institution
# ...

# %%
x = numcols.to_numpy()

# %%
x
# Out:
# array([[0.93, 1.8 , 2.29, ..., 2.79, 1.82, 2.42],
#        [1.02, 2.2 , 2.66, ..., 2.63, 1.86, 2.32],
#        [1.22, 0.8 , 0.54, ..., 2.8 , 1.31, 2.5 ],
#        ...,
#        [0.61, 1.32, 0.67, ..., 2.81, 1.34, 3.02],
#        [0.93, 0.2 , 0.13, ..., 2.98, 1.12, 2.46],
#        [0.93, 0.56, 1.13, ..., 2.87, 1.34, 2.4 ]])

# %%
from scipy.cluster import hierarchy as hi

# %%
lk = hi.linkage(x, method="ward")
ddg = hi.dendrogram(lk)

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters=4)
ylabel = hc.fit_predict(x)

# %%
ylabel
# Out:
# array([2, 2, 0, 0, 1, 0, 0, 0, 1, 3, 1, 3, 2, 2, 2, 1, 0, 1, 1, 2, 0, 3,
#        0, 0, 1, 2, 2, 0, 0, 2, 2, 2, 1, 3, 0, 0, 0, 0, 2, 0, 3, 0, 0, 3,
#        3, 0, 3, 0, 3, 2, 3, 2, 3, 1, 0, 0, 2, 0, 2, 1, 2, 0, 0, 0, 3, 0,
#        0, 0, 0, 0, 0, 2, 3, 2, 1, 1, 0, 2, 0, 3, 0, 1, 0, 0, 1, 3, 0, 0,
#        1, 0, 0, 0, 2, 2, 1, 0, 2, 1, 2, 3, 0, 0, 1, 0, 0, 2, 1, 0, 1, 1,
#        3, 0, 3, 0, 2, 3, 1, 3, 0, 0, 1, 3, 1, 1, 0, 0, 0, 1, 3, 0, 0, 1,
#        1, 1, 3, 1, 1, 1, 0, 0, 3, 0, 3, 0, 0, 3, 3, 2, 1, 1, 3, 3, 0, 3,
#        3, 0, 3, 0, 1, 0, 0, 0, 3, 0, 0, 0, 2, 1, 2, 0, 3, 0, 0, 0, 0, 3,
#        3, 0, 0, 0, 0, 1, 1, 0, 2, 3, 3, 0, 1, 0, 2, 2, 0, 3, 3, 0, 0, 2,
#        0, 1, 2, 3, 2, 0, 0, 0, 3, 0, 0, 0, 0, 2, 3, 0, 0, 1, 0, 0, 1, 2,
#        3, 0, 1, 0, 2, 3, 1, 0, 3, 2, 0, 1, 0, 0, 1, 3, 1, 3, 1, 0, 2, 1,
#        3, 3, 0, 0, 0, 1, 0, 3, 1, 0, 2, 2, 0, 3, 0, 1, 0, 1, 1, 1, 0, 2,
#        0, 1, 2, 1, 3, 1, 3, 0, 1, 2, 1, 0, 1, 3, 0, 3, 0, 0, 2, 1, 3, 0,
# ...

# %%
df["hyc"] = ylabel

# %%
df
# Out:
#       user_id  art_galleries  dance_clubs  juice bars  restaurants  museums  \
# 1      User 1           0.93         1.80        2.29         0.62     0.80
# 2      User 2           1.02         2.20        2.66         0.64     1.42
# 3      User 3           1.22         0.80        0.54         0.53     0.24
# 4      User 4           0.45         1.80        0.29         0.57     0.46
# 5      User 5           0.51         1.20        1.18         0.57     1.54
# ..        ...            ...          ...         ...          ...      ...
# 976  User 976           0.74         1.12        0.30         0.53     0.88
# 977  User 977           1.25         0.92        1.12         0.38     0.78
# 978  User 978           0.61         1.32        0.67         0.43     1.30
# 979  User 979           0.93         0.20        0.13         0.43     0.30
# 980  User 980           0.93         0.56        1.13         0.51     1.34
#
# ...

# %%
df["hyc"].value_counts()
# Out:
# 0    438
# 1    211
# 3    173
# 2    158
# Name: hyc, dtype: int64

# %%
df[df.hyc==1].describe()
# Out:
#        art_galleries  dance_clubs  juice bars  restaurants     museums  \
# count     211.000000   211.000000  211.000000   211.000000  211.000000
# mean        1.011185     1.539526    1.316161     0.665118    1.279810
# std         0.382501     0.636159    0.467178     0.453386    0.476551
# min         0.380000     0.040000    0.140000     0.240000    0.300000
# 25%         0.770000     1.040000    1.120000     0.490000    0.900000
# 50%         0.930000     1.480000    1.330000     0.540000    1.300000
# 75%         1.135000     1.960000    1.610000     0.640000    1.540000
# max         3.220000     3.640000    2.490000     3.440000    3.300000
#
#           resorts  parks/picnis_spot     beaches    theaters  \
# count  211.000000         211.000000  211.000000  211.000000
# mean     2.299384           3.183649    2.820237    1.574218
# std      0.415810           0.005644    0.124271    0.302955
# min      1.280000           3.170000    2.540000    0.960000
# ...

# %%
df[df.hyc==0].describe()
# Out:
#        art_galleries  dance_clubs  juice bars  restaurants     museums  \
# count     438.000000   438.000000  438.000000   438.000000  438.000000
# mean        0.894749     1.217352    0.637169     0.469612    0.678311
# std         0.332426     0.343142    0.486490     0.226742    0.278843
# min         0.350000     0.000000    0.130000     0.150000    0.060000
# 25%         0.670000     1.040000    0.240000     0.370000    0.480000
# 50%         0.830000     1.200000    0.430000     0.430000    0.700000
# 75%         1.020000     1.400000    0.960000     0.530000    0.880000
# max         2.220000     2.400000    2.320000     3.100000    1.380000
#
#           resorts  parks/picnis_spot     beaches    theaters  \
# count  438.000000         438.000000  438.000000  438.000000
# mean     1.441233           3.177055    2.846575    1.485365
# std      0.359238           0.005433    0.145953    0.326209
# min      0.140000           3.160000    2.480000    0.740000
# ...

# %%
df.groupby("hyc")[["art_galleries","dance_clubs","juice bars","restaurants","museums","resorts","parks/picnis_spot","beaches","theaters","religious_institution"]].mean()
# Out:
#      art_galleries  dance_clubs  juice bars  restaurants   museums   resorts  \
# hyc
# 0         0.894749     1.217352    0.637169     0.469612  0.678311  1.441233
# 1         1.011185     1.539526    1.316161     0.665118  1.279810  2.299384
# 2         0.825380     1.288861    2.342785     0.559937  1.096203  2.140380
# 3         0.807283     1.525318    0.382023     0.504913  1.043931  2.031387
#
#      parks/picnis_spot   beaches  theaters  religious_institution
# hyc
# 0             3.177055  2.846575  1.485365               2.952831
# 1             3.183649  2.820237  1.574218               2.586351
# 2             3.191899  2.801392  1.583038               2.539114
# 3             3.177457  2.854740  1.764046               2.907514

# %%
plt.scatter(x[ylabel==0,0], x[ylabel==0,1], s=100, c="red", label="Cluster1")
plt.scatter(x[ylabel==1,0], x[ylabel==1,1], s=100, c="blue", label="Cluster2")
plt.scatter(x[ylabel==2,0], x[ylabel==2,1], s=100, c="green", label="Cluster3")
plt.scatter(x[ylabel==3,0], x[ylabel==3,1], s=100, c="yellow", label="Cluster4")

plt.title("Clusters of user")
plt.legend()
plt.show()

# %%
x = df.drop(["user_id","hyc"],axis = 1)
y = df["hyc"]

# %%
x
# Out:
#      art_galleries  dance_clubs  juice bars  restaurants  museums  resorts  \
# 1             0.93         1.80        2.29         0.62     0.80     2.42
# 2             1.02         2.20        2.66         0.64     1.42     3.18
# 3             1.22         0.80        0.54         0.53     0.24     1.54
# 4             0.45         1.80        0.29         0.57     0.46     1.52
# 5             0.51         1.20        1.18         0.57     1.54     2.02
# ..             ...          ...         ...          ...      ...      ...
# 976           0.74         1.12        0.30         0.53     0.88     1.38
# 977           1.25         0.92        1.12         0.38     0.78     1.68
# 978           0.61         1.32        0.67         0.43     1.30     1.78
# 979           0.93         0.20        0.13         0.43     0.30     0.40
# 980           0.93         0.56        1.13         0.51     1.34     2.36
#
#      parks/picnis_spot  beaches  theaters  religious_institution
# ...

# %%
y
# Out:
# 1      2
# 2      2
# 3      0
# 4      0
# 5      1
#       ..
# 976    0
# 977    0
# 978    0
# 979    0
# 980    1
# Name: hyc, Length: 980, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y,stratify=y,test_size=0.3, random_state=1)

# %%
def mymodel(model):
    model.fit(xtrain, ytrain)
    ypred = model.predict(xtest)
    
    train = model.score(xtrain, ytrain)
    test = model.score(xtest, ytest)
    
    print(f"Training Accuracy : {train}\nTesting Accuracy : {test}\n\n")
    print(classification_report(ytest, ypred))
    return model

# %%
from sklearn.metrics import classification_report
from sklearn.naive_bayes import MultinomialNB, GaussianNB, BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier

# %%
bnb = mymodel(MultinomialNB())
# Out:
# Training Accuracy : 0.6355685131195336
# Testing Accuracy : 0.6258503401360545
#
#
#               precision    recall  f1-score   support
#
#            0       0.59      1.00      0.75       132
#            1       0.58      0.40      0.47        63
#            2       0.96      0.57      0.72        47
#            3       0.00      0.00      0.00        52
#
#     accuracy                           0.63       294
#    macro avg       0.54      0.49      0.48       294
# weighted avg       0.55      0.63      0.55       294

# %%
from sklearn.svm import SVC

# %%
svm = SVC()
svm = svm.fit(xtrain,ytrain)
pred = svm.predict(xtest)

from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

print(classification_report(ytest,pred))
train = svm.score(xtrain,ytrain)
test = svm.score(xtest,ytest)
print(train)
print(test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91       132
#            1       0.85      0.87      0.86        63
#            2       0.92      0.96      0.94        47
#            3       0.91      0.79      0.85        52
#
#     accuracy                           0.89       294
#    macro avg       0.89      0.89      0.89       294
# weighted avg       0.90      0.89      0.89       294
#
# 0.9081632653061225
# 0.8945578231292517
