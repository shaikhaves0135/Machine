# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C://Users/HP/Downloads/Automobile_data (1).csv")

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df["normalized-losses"].value_counts()
# Out:
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 106     4
# 93      4
# 118     4
# 148     4
# 122     4
# 83      3
# 125     3
# 154     3
# 115     3
# 137     3
# 101     3
# 119     2
# 87      2
# 89      2
# 192     2
# 197     2
# 158     2
# 81      2
# 188     2
# 194     2
# 153     2
# 129     2
# 108     2
# 110     2
# 164     2
# 145     2
# 113     2
# 256     1
# 107     1
# 90      1
# 231     1
# 142     1
# 121     1
# 78      1
# 98      1
# 186     1
# 77      1
# Name: normalized-losses, dtype: int64

# %%
df.replace("?",np.nan,inplace = True)

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df.drop(columns="normalized-losses",axis = 1,inplace = True)

# %%
df
# Out:
#      symboling         make fuel-type aspiration num-of-doors   body-style  \
# 0            3  alfa-romero       gas        std          two  convertible
# 1            3  alfa-romero       gas        std          two  convertible
# 2            1  alfa-romero       gas        std          two    hatchback
# 3            2         audi       gas        std         four        sedan
# 4            2         audi       gas        std         four        sedan
# ..         ...          ...       ...        ...          ...          ...
# 200         -1        volvo       gas        std         four        sedan
# 201         -1        volvo       gas      turbo         four        sedan
# 202         -1        volvo       gas        std         four        sedan
# 203         -1        volvo    diesel      turbo         four        sedan
# 204         -1        volvo       gas      turbo         four        sedan
#
# ...

# %%
df.drop(columns=["symboling","peak-rpm"],axis = 1,inplace = True)

# %%
df
# Out:
#             make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0    alfa-romero       gas        std          two  convertible          rwd
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 3           audi       gas        std         four        sedan          fwd
# 4           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 200        volvo       gas        std         four        sedan          rwd
# 201        volvo       gas      turbo         four        sedan          rwd
# 202        volvo       gas        std         four        sedan          rwd
# 203        volvo    diesel      turbo         four        sedan          rwd
# 204        volvo       gas      turbo         four        sedan          rwd
#
# ...

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 0 to 204
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               193 non-null    object
#  1   fuel-type          193 non-null    object
#  2   aspiration         193 non-null    object
#  3   num-of-doors       193 non-null    object
#  4   body-style         193 non-null    object
#  5   drive-wheels       193 non-null    object
#  6   engine-location    193 non-null    object
#  7   wheel-base         193 non-null    float64
#  8   length             193 non-null    float64
#  9   width              193 non-null    float64
#  10  height             193 non-null    float64
#  11  curb-weight        193 non-null    int64
#  12  engine-type        193 non-null    object
#  13  num-of-cylinders   193 non-null    object
#  14  engine-size        193 non-null    int64
#  15  fuel-system        193 non-null    object
# ...

# %%
df['horsepower'] = df['horsepower'].astype('float64')

# %%
df['price'] = df['price'].astype('float64')

# %%
df['compression-ratio'] = df['compression-ratio'].astype('float64')

# %%
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = (150)
sns.boxplot(x = 'price', y = 'make', data = df)
plt.grid()

# %%
df[(df["make"] == "audi") & (df["price"] > 20000)]
# Out:
#    make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 8  audi       gas      turbo         four      sedan          fwd
#
#   engine-location  wheel-base  length  width  ...  num-of-cylinders  \
# 8           front       105.8   192.7   71.4  ...              five
#
#    engine-size fuel-system  bore  stroke compression-ratio horsepower  \
# 8          131        mpfi  3.13     3.4               8.3      140.0
#
#   city-mpg  highway-mpg    price
# 8       17           20  23875.0
#
# [1 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 0 to 204
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               193 non-null    object
#  1   fuel-type          193 non-null    object
#  2   aspiration         193 non-null    object
#  3   num-of-doors       193 non-null    object
#  4   body-style         193 non-null    object
#  5   drive-wheels       193 non-null    object
#  6   engine-location    193 non-null    object
#  7   wheel-base         193 non-null    float64
#  8   length             193 non-null    float64
#  9   width              193 non-null    float64
#  10  height             193 non-null    float64
#  11  curb-weight        193 non-null    int64
#  12  engine-type        193 non-null    object
#  13  num-of-cylinders   193 non-null    object
#  14  engine-size        193 non-null    int64
#  15  fuel-system        193 non-null    object
# ...

# %%
df['bore'] = df['bore'].astype('float64')
df['stroke'] = df['stroke'].astype('float64')

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()
catcols = df.select_dtypes(object).columns

# %%
catcols
# Out:
# Index(['make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style',
#        'drive-wheels', 'engine-location', 'engine-type', 'num-of-cylinders',
#        'fuel-system'],
#       dtype='object')

# %%
df[catcols] = oe.fit_transform(df[catcols])

# %%
x = df.drop(columns="price",axis = 1)
y = df["price"]
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,random_state = 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
model = lr.fit(xtrain,ytrain)
pred = model.predict(xtest)

# %%
pred
# Out:
# array([ 7206.64580305, 13014.97115823,  9463.58378096, 12889.30198542,
#         7470.38274159, 19460.70211394,  8616.01988537,  6667.80543509,
#         6565.56300906, 13738.28505934, 14752.20291082,  6679.09031542,
#        18550.9128549 , 26487.46498975, 14601.35220382, 13293.1342772 ,
#        21482.15586366,  6941.31719547, 13143.09507649, 42543.24821839,
#        10963.13030217, 17769.1001841 , 45309.79700954, 32528.        ,
#         8334.15846582, 20746.11078212, 12776.50416027, 30418.67906019,
#         4937.09911564, 20268.19836137, 20619.88530281, 18415.79214268,
#         7292.59075552,  5901.93608727, 20396.35568111,  5931.29080078,
#        12630.15458722, 12803.59910243, 15190.89805001, 19810.75987282,
#         8450.59498709,  6694.79509831, 43286.89653757,  5207.72159318,
#        16499.48818447, 11324.81822428, 32873.37992229, 18371.40560082,
#        10619.15675938])

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
r2_score(ytest,pred)
# Out:
# 0.9034052185854657

# %%
train = model.score(xtrain,ytrain)
test = model.score(xtest,ytest)
print(train)
print(test)
# Out:
# 0.8836384152229378
# 0.9034052185854657
